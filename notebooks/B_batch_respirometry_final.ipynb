# %% [markdown]
# ## Batch Parameters and Aggregation
# This section lets you set parameters, call the R script for one or more CSVs, and aggregate results into a long-format summary where each row is a channel with `uL_mg_hr`, `temp_C`, and placeholder metadata.

# %% [markdown]
# ## Configuration
#
# Set paths and default parameters.

# %%
import pandas as pd
import subprocess
from pathlib import Path

# Paths
#First analyses sent by Adriana
#DATA_DIR = Path('/Users/oakley/Documents/GitHub/signal_respirometry/data/original_respirometry_Panama2025')

#Final csv and R scripts sent by Adriana December 1
DATA_DIR = Path('/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r')
OUT_DIR = Path('/Users/oakley/Documents/GitHub/signal_respirometry/data/processed')
R_SCRIPT = Path('/Users/oakley/Documents/GitHub/signal_respirometry/scripts/consumption_rate.R')

# Create output directory if needed
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Default parameters
DEFAULT_SAL = 33
DEFAULT_CONTROL = 'Ch1'
DEFAULT_CHANNELS = ['Ch2', 'Ch3', 'Ch4']
DEFAULT_MASSES = [0.00024, 0.00024, 0.00024]  # grams
DEFAULT_VOL_CONTROL = 0.002  # liters
DEFAULT_VOLUMES = [0.002, 0.002, 0.002]  # liters
DEFAULT_START_HOUR = 1
DEFAULT_END_HOUR = 8
DEFAULT_MICROBIAL_CUTOFF = 5

# %% [markdown]
# ## Define Trial Runs
#
# Each run is a dictionary with trial-specific parameters and meta-data.

# %%
# Define your runs here
# Each run can override defaults or use them

# Trial 1 (10 Nov 2025) - night environment
# Box2: small vessels (2ml), 1 animal each
# Box3: cylinders (260-268ml), 20 animals each
# Newbox: small vessels (2ml), 1 animal each - using newpyro CSV format

runs = [
    {
        'trial': 'trial1',
        'brick': 'box2',
        'csv': DATA_DIR / 'box2-trial1.csv',
        'masses': [0.0002263, 0.0002099, 0.0002703],  # measured (1 animal per channel)
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '10Nov2025',
            'environment': 'night'
        }
    },

    {
        'trial': 'trial1',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial1.csv',
        'masses': [0.0076, 0.007222222, 0.007333333],  # 20 animals × 0.00024 = 0.0048 g
        'volumes': [0.264, 0.262, 0.260],  # cylinders in ml → L
        'vol_control': 0.268,  # Ch1 control cylinder
        'metadata': {
            'vessel': 'cylinder',
            'date': '10Nov2025',
            'environment': 'night'
        }
    },
    {
        'trial': 'trial1',
        'brick': 'newbox',
        'csv': DATA_DIR / 'newpyro-trial1.csv',  # Using newpyro CSV format
        'masses': [0.0002513, 0.000297, 0.0001811],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '10Nov2025',
            'environment': 'night'
        }
    },
    # Trial 2 (11 Nov 2025) - night environment
    # NOTE: Box2 and Box3 had crashes during this trial
    # Only Newbox: medium vessels (25ml), 5 animals each
    {
        'trial': 'trial2',
        'brick': 'newbox',
        'csv': DATA_DIR / 'newpyro-trial2.csv',  # Using newpyro CSV format
        'masses': [0.0011, 0.001125, 0.0011],  # 5 animals × 0.00024 = 0.0012 g
        'volumes': [0.025, 0.025, 0.025],  # 25 ml each
        'vol_control': 0.025,
        'metadata': {
            'vessel': 'medium',
            'date': '11Nov2025',
            'environment': 'night'
        }
    },
    # Trial 3 (12 Nov 2025) - night environment
    # Box2: cylinders (260, 262, 264, 268 ml), 20 animals each
    # Box3: medium vessels (25ml), 5 animals each
    # Newbox: small vessels (2ml), 1 animal each

#Dry mass in grams. As example, using Daphnia pulex adult dry mass of 240 ug.The mass number is the channel number.
    {
        'trial': 'trial3',
        'brick': 'box2',
        'csv': DATA_DIR / 'box2-trial3.csv',
        'masses': [0.0049, 0.0047, 0.005058824],  # 20 animals × 0.00024 = 0.0048 g
        'volumes': [0.260, 0.262, 0.264],  # cylinders Ch2, Ch3, Ch4 in L
        'vol_control': 0.268,  # Ch1 control cylinder
        'metadata': {
            'vessel': 'cylinder',
            'date': '12Nov2025',
            'environment': 'night',
            'notes': 'Ch2 closest to GoPro, Ch4 farthest from GoPro'
        }
    },
    {
        'trial': 'trial3',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial3.csv',
        'masses': [0.0011, 0.001, 0.001125],  # 5 animals × 0.00024 = 0.0012 g
        'volumes': [0.025, 0.025, 0.025],  # 25 ml each
        'vol_control': 0.025,
        'metadata': {
            'vessel': 'medium',
            'date': '12Nov2025',
            'environment': 'night'
        }
    },
    {
        'trial': 'trial3',
        'brick': 'newbox',
        'csv': DATA_DIR / 'newpyro-trial3.csv',  # Using newpyro CSV format
        'masses': [0.0002168, 0.0001989, 0.0002552],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'microbial_cutoff_hour': 4,  # match the cutoff hour used in R script
        'metadata': {
            'vessel': 'small',
            'date': '12Nov2025',
            'environment': 'night'
        }
    },
    # Trial 4 (13 Nov 2025) - night environment
    # Box2: small vessels (2ml), 1 animal each
    # Box3: small vessels (2ml), 1 animal each
    # Newbox: cylinders (260, 262, 264, 268 ml), 20 animals each
    {
        'trial': 'trial4',
        'brick': 'box2',
        'csv': DATA_DIR / 'box2-trial4.csv',
        'masses': [0.0002187, 0.0003741, 0.0002074],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '13Nov2025',
            'environment': 'night'
        }
    },
    {
        'trial': 'trial4',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial4.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '13Nov2025',
            'environment': 'night'
        }
    },

#Default parameters give negative rates. The early microbial rate (control) looks really high
#Perhaps that is an artifact of non-mixing or somthing?
#Try to set start hour to 3
    {
        'trial': 'trial4',
        'brick': 'newbox',
        'start_hour': 3,
        'csv': DATA_DIR / 'newpyro-trial4.csv',
        'masses': [0.0048, 0.0048, 0.0048],  # 20 animals per cylinder
        'volumes': [0.260, 0.262, 0.264],  # cylinders Ch2, Ch3, Ch4
        'vol_control': 0.268,  # Ch1 control cylinder
        'metadata': {
            'vessel': 'cylinder',
            'date': '13Nov2025',
            'environment': 'night'
        }
    },
    # Trial 4.5 (14 Nov 2025) - day environment (same animals as Trial 4)
    {
        'trial': 'trial4.5',
        'brick': 'box2',
        'csv': DATA_DIR / 'box2-trial4-light.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '14Nov2025',
            'environment': 'day',
            'notes': 'Same animals as trial4'
        }
    },
    {
        'trial': 'trial4.5',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial4-light.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '14Nov2025',
            'environment': 'day',
            'notes': 'Same animals as trial4'
        }
    },
    # Trial 4.5 newbox not available (no CSV provided)

    # Trial 5 (14 Nov 2025) - night environment
    {
        'trial': 'trial5',
        'brick': 'box2',
        'csv': DATA_DIR / 'box2-trial5.csv',
        'channels': ['Ch2', 'Ch3', 'Ch4'],  # Only 3 channels
        'masses': [0.0048, 0.0048],  # 20 animals per cylinder
        'volumes': [0.260, 0.262],  # Ch2=260ml, Ch3=262ml, Ch4=268ml
        'vol_control': 0.268,  # Using Ch4 (268ml) as pseudo-control
        'ignore': 'Ch4',
        'metadata': {
            'vessel': 'cylinder',
            'date': '14Nov2025',
            'environment': 'night',
            'notes': 'One cylinder broke, only 3 channels available'
        }
    },
    {
        'trial': 'trial5',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial5.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '14Nov2025',
            'environment': 'night'
        }
    },
    {
        'trial': 'trial5',
        'brick': 'newbox',
        'csv': DATA_DIR / 'newpyro-trial5.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '14Nov2025',
            'environment': 'night'
        }
    },

    {
        'trial': 'trial5.5',
        'brick': 'newbox',
        'csv': DATA_DIR / 'newpyro-trial5-light.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '15Nov2025',
            'environment': 'day',
            'notes': 'Same animals as trial5'
        }
    },
    # Trial 6 (16 Nov 2025) - day environment
{
        'trial': 'trial6',
        'brick': 'box3',
        'csv': DATA_DIR / 'box3-trial6-light.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '16Nov2025',
            'environment': 'day',
            'notes': 'Ch1 serves as control for both box3 and newbox'
        }
    },

    {
        'trial': 'trial6',
        'brick': 'newbox',
        'csv': DATA_DIR / 'Ostracods-trial6-light-newbox-.csv',
        'control': 'Ch1',
        'control-csv': DATA_DIR / 'Ostracods-trial6-light-box3-16Nov.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '16Nov2025',
            'environment': 'day',
            'notes': 'Ch1 serves as control for both box3 and newbox'
        }
    },
    # Trial 6.5 (16 Nov 2025) - night environment (same animals as Trial 6)
    {
        'trial': 'trial6.5',
        'brick': 'box3',
        'csv': DATA_DIR / 'Ostracods-trial6-dark-box3-16Nov.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '16Nov2025',
            'environment': 'night',
            'notes': 'Ch1 serves as control for both box3 and newbox'
        }
    },
    {
        'trial': 'trial6.5',
        'brick': 'newbox',
        'csv': DATA_DIR / 'Ostracods-trial6-dark-newbox-1.csv',
        'control': 'Ch1',
        'control_csv': DATA_DIR / 'Ostracods-trial6-dark-box3-16Nov.csv',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '16Nov2025',
            'environment': 'night',
            'notes': 'Same animals as trial6; Ch1 serves as control for both box3 and newbox'
        }
    },
    # Trial 7 (17 Nov 2025) - day environment
    {
        'trial': 'trial7',
        'brick': 'newbox',
        'csv': DATA_DIR / 'Ostracods-trial7-light-newbox-.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'control_csv': DATA_DIR / 'Ostracods-trial7-light-box3-17Nov.csv',
        'metadata': {
            'vessel': 'small',
            'date': '17Nov2025',
            'environment': 'day',
            'notes': 'Ch1 serves as control for both box3 and newbox'
        }
    },
        {
        'trial': 'trial7',
        'brick': 'box3',
        'csv': DATA_DIR / 'Ostracods-trial7-light-box3-17Nov.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '17Nov2025',
            'environment': 'day',
            'notes': 'Ch1 serves as control for both box3 and newbox'
        }
    },
    # Trial 7.5 (17 Nov 2025) - night environment (same animals as Trial 7)
    {
        'trial': 'trial7.5',
        'brick': 'newbox',
        'csv': DATA_DIR / 'Ostracods-trial7-dark-newbox-1.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'control_csv': DATA_DIR / 'Ostracods-trial7-dark-box3-17Nov.csv',
        'metadata': {
            'vessel': 'small',
            'date': '17Nov2025',
            'environment': 'night',
            'notes': 'Same animals as trial7; Ch1 serves as control for both box3 and newbox'
        }
    },
    {
        'trial': 'trial7.5',
        'brick': 'box3',
        'csv': DATA_DIR / 'Ostracods-trial7-dark-box3-17Nov.csv',
        'control': 'Ch1',
        'masses': [0.00024, 0.00024, 0.00024],  # 1 animal per channel
        'volumes': [0.002, 0.002, 0.002],  # 2 ml each
        'vol_control': 0.002,
        'metadata': {
            'vessel': 'small',
            'date': '17Nov2025',
            'environment': 'night',
            'notes': 'Same animals as trial7; Ch1 serves as control for both box3 and newbox'
        }
    },
]




#****************** Define Helper functions to call the R Script ******************#

def run_respirometry_analysis(run, defaults=None):
    """
    Call consumption_rate.R for a single run.
    
    Args:
        run: dict with 'csv', 'trial', 'brick', and optional parameters
        defaults: dict with default values for missing parameters
    
    Returns:
        tuple: (success: bool, message: str)
    """
    if defaults is None:
        defaults = {}
    
    csv_path = run['csv']
    if not csv_path.exists():
        return False, f"CSV not found: {csv_path}"
    
    # Build R script arguments
    args = [
        'Rscript', '--vanilla', str(R_SCRIPT),
        '--csv', str(csv_path),
        '--sal', str(run.get('sal', defaults.get('sal', DEFAULT_SAL))),
        '--control', run.get('control', defaults.get('control', DEFAULT_CONTROL)),
        '--channels', ','.join(run.get('channels', defaults.get('channels', DEFAULT_CHANNELS))),
        '--masses', ','.join(str(m) for m in run.get('masses', defaults.get('masses', DEFAULT_MASSES))),
        '--vol_control', str(run.get('vol_control', defaults.get('vol_control', DEFAULT_VOL_CONTROL))),
        '--volumes', ','.join(str(v) for v in run.get('volumes', defaults.get('volumes', DEFAULT_VOLUMES))),
        '--start_hour', str(run.get('start_hour', defaults.get('start_hour', DEFAULT_START_HOUR))),
        '--end_hour', str(run.get('end_hour', defaults.get('end_hour', DEFAULT_END_HOUR))),
        '--microbial_cutoff_hour', str(run.get('microbial_cutoff_hour', defaults.get('microbial_cutoff_hour', DEFAULT_MICROBIAL_CUTOFF))),
        '--out', str(OUT_DIR),
    ]
    
    # Add optional flags if specified
    if run.get('mask_channels', False):
        args += ['--mask_channels', 'true']
    if 'cutoff_inclusive' in run:
        args += ['--cutoff_inclusive', 'true' if run['cutoff_inclusive'] else 'false']
    if run.get('debug', False):
        args += ['--debug', 'true']
    if 'ignore' in run:
        args += ['--ignore', run['ignore']]
    
    # Run R script
    try:
        result = subprocess.run(
            args,
            check=True,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        return True, f"Success: {run['trial']}-{run['brick']}"
    except subprocess.CalledProcessError as e:
        error_msg = f"Failed: {run['trial']}-{run['brick']}\n"
        if e.stderr:
            error_msg += f"Error: {e.stderr}"
        return False, error_msg

# %% [markdown]
# ## Plot Data

# %%
# Batch Data QC Plots (Collapsible)
import matplotlib.pyplot as plt
from IPython.display import display, HTML

for run in runs:
    csv_path = run['csv']
    try:
        df = pd.read_csv(csv_path)
    except Exception as e:
        print(f'Could not read {csv_path}: {e}')
        continue
    fig, ax = plt.subplots(figsize=(6, 3))
    # Always plot Ch1 if present
    if 'Ch1' in df.columns:
        ax.plot(df['hours'], df['Ch1'], label='Ch1', linestyle='--', color='black')
    # Plot all other channels in run config
    for ch in run.get('channels', DEFAULT_CHANNELS):
        if ch in df.columns:
            ax.plot(df['hours'], df[ch], label=ch)
    # Optionally highlight the control channel if specified and not Ch1
    if 'control' in run and run['control'] in df.columns and run['control'] != 'Ch1':
        ax.plot(df['hours'], df[run['control']], label=f"{run['control']} (control)", linestyle=':', color='red')
    vessel = run.get('metadata', {}).get('vessel', '')
    environment = run.get('metadata', {}).get('environment', '')
    ax.set_title(f"{run['trial']} - {run['brick']} | {vessel} | {environment}")
    ax.set_xlabel('Hours')
    ax.set_ylabel('O₂ (µmol/L)')
    ax.legend()
    plt.tight_layout()
    # Wrap each plot in a collapsible HTML details tag
    display(HTML(f'<details><summary>{run["trial"]} - {run["brick"]}</summary>'))
    display(fig)
    display(HTML('</details>'))
    plt.close(fig)
# Out:
# <details><summary>trial1 - box2</summary>
# </details>
# <details><summary>trial1 - box3</summary>
# </details>
# <details><summary>trial1 - newbox</summary>
# </details>
# <details><summary>trial2 - newbox</summary>
# </details>
# <details><summary>trial3 - box2</summary>
# </details>
# <details><summary>trial3 - box3</summary>
# </details>
# <details><summary>trial3 - newbox</summary>
# </details>
# <details><summary>trial4 - box2</summary>
# </details>
# <details><summary>trial4 - box3</summary>
# </details>
# <details><summary>trial4 - newbox</summary>
# </details>
# <details><summary>trial4.5 - box2</summary>
# </details>
# <details><summary>trial4.5 - box3</summary>
# </details>
# <details><summary>trial5 - box2</summary>
# </details>
# <details><summary>trial5 - box3</summary>
# </details>
# <details><summary>trial5 - newbox</summary>
# </details>
# <details><summary>trial5.5 - newbox</summary>
# </details>
# <details><summary>trial6 - box3</summary>
# </details>
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-light-newbox-.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-light-newbox-.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-box3-16Nov.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-box3-16Nov.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-newbox-1.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-newbox-1.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-newbox-.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-newbox-.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-box3-17Nov.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-box3-17Nov.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-newbox-1.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-newbox-1.csv'
# Could not read /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-box3-17Nov.csv: [Errno 2] No such file or directory: '/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-box3-17Nov.csv'

# %%
# --- Run and view a single run (ad hoc) ---
# Example: rerun and inspect just trial 4 newbox
single_run = next(r for r in runs if r['trial'] == 'trial4' and r['brick'] == 'newbox')
success, message = run_respirometry_analysis(single_run)
print(message)

# Load and display the summary for this run, one row per channel, with extra parameters
csv_name = single_run['csv'].name
summary_path = OUT_DIR / f"{csv_name}_R_summary.csv"
if summary_path.exists():
    r_df = pd.read_csv(summary_path)
    # Reshape: gather all *_uL_mg_hr columns into rows
    channel_cols = [col for col in r_df.columns if col.endswith('_uL_mg_hr')]
    rows = []
    for col in channel_cols:
        channel = col.replace('_uL_mg_hr', '')
        value = r_df[col].iloc[0]
        row = {
            'channel': channel,
            'uL_mg_hr': value,
            'temp_C': r_df['temp_C'].iloc[0] if 'temp_C' in r_df.columns else None,
            'start_hour': single_run.get('start_hour', DEFAULT_START_HOUR),
            'box': single_run.get('brick', None),
            'vessel': single_run.get('metadata', {}).get('vessel', None)
        }
        rows.append(row)
    display(pd.DataFrame(rows))
else:
    print(f"Summary not found: {summary_path}")
# Out:
# CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial4-newbox-13Nov.csv
#   channel  uL_mg_hr  temp_C  start_hour     box    vessel
# 0     Ch2 -0.244429  27.189           3  newbox  cylinder
# 1     Ch3 -0.594671  27.189           3  newbox  cylinder
# 2     Ch4 -0.678012  27.189           3  newbox  cylinder

# %% [markdown]
# ## Run Batch Data Analyses

# %%
# Process all runs
results = []

for run in runs:
    run_id = f"{run['trial']}-{run['brick']}"
    print(f"Processing {run_id}...")
    success, message = run_respirometry_analysis(run)
    results.append({
        'trial': run['trial'],
        'brick': run['brick'],
        'success': success,
        'message': message
    })
    if not success:
        print(f"  ❌ {message}")
    else:
        print(f"  ✓ {message}")

# Summary
results_df = pd.DataFrame(results)
print(f"\n{'='*60}")
print(f"Completed: {results_df['success'].sum()}/{len(results_df)} runs succeeded")
print(f"{'='*60}")
display(results_df)
# Out:
# Processing trial1-box2...
#   ✓ Success: trial1-box2
# Processing trial1-box3...
#   ✓ Success: trial1-box3
# Processing trial1-newbox...
#   ✓ Success: trial1-newbox
# Processing trial2-newbox...
#   ✓ Success: trial2-newbox
# Processing trial3-box2...
#   ✓ Success: trial3-box2
# Processing trial3-box3...
#   ✓ Success: trial3-box3
# Processing trial3-newbox...
#   ✓ Success: trial3-newbox
# Processing trial4-box2...
#   ✓ Success: trial4-box2
# Processing trial4-box3...
#   ✓ Success: trial4-box3
# Processing trial4-newbox...
#   ✓ Success: trial4-newbox
# Processing trial4.5-box2...
#   ✓ Success: trial4.5-box2
# Processing trial4.5-box3...
#   ❌ Failed: trial4.5-box3
# Error: Error: Missing channel columns: Ch2
# Execution halted
#
# Processing trial5-box2...
#   ❌ Failed: trial5-box2
# Error: Error: Missing channel columns: Ch3
# Execution halted
#
# Processing trial5-box3...
#   ✓ Success: trial5-box3
# Processing trial5-newbox...
#   ✓ Success: trial5-newbox
# Processing trial5.5-newbox...
#   ✓ Success: trial5.5-newbox
# Processing trial6-box3...
#   ❌ Failed: trial6-box3
# Error: Error: Missing channel columns: Ch1
# Execution halted
#
# Processing trial6-newbox...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-light-newbox-.csv
# Processing trial6.5-box3...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-box3-16Nov.csv
# Processing trial6.5-newbox...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial6-dark-newbox-1.csv
# Processing trial7-newbox...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-newbox-.csv
# Processing trial7-box3...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-light-box3-17Nov.csv
# Processing trial7.5-newbox...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-newbox-1.csv
# Processing trial7.5-box3...
#   ❌ CSV not found: /Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/Ostracods-trial7-dark-box3-17Nov.csv
#
# ============================================================
# Completed: 14/24 runs succeeded
# ============================================================
#        trial   brick  success  \
# 0     trial1    box2     True
# 1     trial1    box3     True
# 2     trial1  newbox     True
# 3     trial2  newbox     True
# 4     trial3    box2     True
# 5     trial3    box3     True
# 6     trial3  newbox     True
# 7     trial4    box2     True
# 8     trial4    box3     True
# 9     trial4  newbox     True
# 10  trial4.5    box2     True
# 11  trial4.5    box3    False
# 12    trial5    box2    False
# 13    trial5    box3     True
# 14    trial5  newbox     True
# 15  trial5.5  newbox     True
# 16    trial6    box3    False
# 17    trial6  newbox    False
# 18  trial6.5    box3    False
# 19  trial6.5  newbox    False
# 20    trial7  newbox    False
# 21    trial7    box3    False
# 22  trial7.5  newbox    False
# 23  trial7.5    box3    False
#
#                                               message
# 0                                Success: trial1-box2
# 1                                Success: trial1-box3
# 2                              Success: trial1-newbox
# 3                              Success: trial2-newbox
# 4                                Success: trial3-box2
# 5                                Success: trial3-box3
# 6                              Success: trial3-newbox
# 7                                Success: trial4-box2
# 8                                Success: trial4-box3
# 9                              Success: trial4-newbox
# 10                             Success: trial4.5-box2
# 11  Failed: trial4.5-box3\nError: Error: Missing c...
# 12  Failed: trial5-box2\nError: Error: Missing cha...
# 13                               Success: trial5-box3
# 14                             Success: trial5-newbox
# 15                           Success: trial5.5-newbox
# 16  Failed: trial6-box3\nError: Error: Missing cha...
# 17  CSV not found: /Users/oakley/Documents/GitHub/...
# 18  CSV not found: /Users/oakley/Documents/GitHub/...
# 19  CSV not found: /Users/oakley/Documents/GitHub/...
# 20  CSV not found: /Users/oakley/Documents/GitHub/...
# 21  CSV not found: /Users/oakley/Documents/GitHub/...
# 22  CSV not found: /Users/oakley/Documents/GitHub/...
# 23  CSV not found: /Users/oakley/Documents/GitHub/...

# %% [markdown]
# ## Run Analysis of Single Trial

# %%
# --- Run and view a single run (ad hoc) ---

single_run = next(r for r in runs if r['trial'] == 'trial4' and r['brick'] == 'box2')
success, message = run_respirometry_analysis(single_run)
print(message)

# Load and display the summary for this run, one row per channel, with extra parameters
csv_name = single_run['csv'].name
summary_path = OUT_DIR / f"{csv_name}_R_summary.csv"
if summary_path.exists():
    r_df = pd.read_csv(summary_path)
    # Reshape: gather all *_uL_mg_hr columns into rows
    channel_cols = [col for col in r_df.columns if col.endswith('_uL_mg_hr')]
    rows = []
    for col in channel_cols:
        channel = col.replace('_uL_mg_hr', '')
        value = r_df[col].iloc[0]
        row = {
            'channel': channel,
            'uL_mg_hr': value,
            'temp_C': r_df['temp_C'].iloc[0] if 'temp_C' in r_df.columns else None,
            'start_hour': single_run.get('start_hour', DEFAULT_START_HOUR),
            'box': single_run.get('brick', None),
            'vessel': single_run.get('metadata', {}).get('vessel', None)
        }
        rows.append(row)
    display(pd.DataFrame(rows))
else:
    print(f"Summary not found: {summary_path}")
## Load and Aggregate Results
# Out:
# Success: trial4-box2
#   channel  uL_mg_hr  temp_C  start_hour   box vessel
# 0     Ch2  1.101950  27.142           1  box2  small
# 1     Ch3  0.901494  27.142           1  box2  small
# 2     Ch4  1.000536  27.142           1  box2  small

# %%
import subprocess

cmd = [
    "Rscript",
    "--vanilla",
    "/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r/box2-trial4.R",
]

result = subprocess.run(cmd, text=True, capture_output=True)
print(result.stdout)
print(result.stderr)
print("Exit code:", result.returncode)
# Out:
# [1] 1.10195
# [1] 0.9014939
# [1] 1.000536
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Exit code: 0

# %%
import pandas as pd

# Collect all R summary CSVs
summary_rows = []

for run in runs:
    csv_name = run['csv'].name
    summary_path = OUT_DIR / f"{csv_name}_R_summary.csv"
    
    run_id = f"{run['trial']}-{run['brick']}"
    if not summary_path.exists():
        print(f"Warning: Summary not found for {run_id}")
        continue
    
    # Read R summary
    r_df = pd.read_csv(summary_path)
    
    # Get channels from run config
    channels = run.get('channels', DEFAULT_CHANNELS)
    
    # Extract per-channel results
    for ch in channels:
        col = f'{ch}_uL_mg_hr'
        if col in r_df.columns:
            row = {
                'trial': run['trial'],
                'brick': run['brick'],
                'file': str(run['csv']),
                'channel': ch,
                'uL_mg_hr': float(r_df[col].iloc[0]),
                'temp_C': float(r_df['temp_C'].iloc[0]) if 'temp_C' in r_df.columns else None,
            }
            # Add metadata if present
            if 'metadata' in run:
                row.update(run['metadata'])
            summary_rows.append(row)

# Create aggregated dataframe
if summary_rows:
    agg_df = pd.DataFrame(summary_rows)
    
    # Save aggregated summary
    agg_path = OUT_DIR / 'batch_summary.csv'
    agg_df.to_csv(agg_path, index=False)
    print(f"Aggregated summary saved to: {agg_path}")
    
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    display(agg_df)

else:    print("No results to aggregate.")
# Out:
# Warning: Summary not found for trial4.5-box3
# Warning: Summary not found for trial5-box2
# Warning: Summary not found for trial6-box3
# Aggregated summary saved to: /Users/oakley/Documents/GitHub/signal_respirometry/data/processed/batch_summary.csv
#        trial   brick                                               file  \
# 0     trial1    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 1     trial1    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 2     trial1    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 3     trial1    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 4     trial1    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 5     trial1    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 6     trial1  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 7     trial1  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 8     trial1  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 9     trial2  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 10    trial2  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 11    trial2  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 12    trial3    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 13    trial3    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 14    trial3    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 15    trial3    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 16    trial3    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 17    trial3    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 18    trial3  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 19    trial3  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 20    trial3  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 21    trial4    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 22    trial4    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 23    trial4    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 24    trial4    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 25    trial4    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 26    trial4    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 27    trial4  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 28    trial4  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 29    trial4  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 30  trial4.5    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 31  trial4.5    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 32  trial4.5    box2  /Users/oakley/Documents/GitHub/signal_respirom...
# 33    trial5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 34    trial5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 35    trial5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 36    trial5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 37    trial5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 38    trial5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 39  trial5.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 40  trial5.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 41  trial5.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 42    trial6  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 43    trial6  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 44    trial6  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 45  trial6.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 46  trial6.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 47  trial6.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 48  trial6.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 49  trial6.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 50  trial6.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 51    trial7  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 52    trial7  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 53    trial7  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 54    trial7    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 55    trial7    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 56    trial7    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 57  trial7.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 58  trial7.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 59  trial7.5  newbox  /Users/oakley/Documents/GitHub/signal_respirom...
# 60  trial7.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 61  trial7.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
# 62  trial7.5    box3  /Users/oakley/Documents/GitHub/signal_respirom...
#
#    channel  uL_mg_hr  temp_C    vessel       date environment  \
# 0      Ch2  2.708969  27.948     small  10Nov2025       night
# 1      Ch3  3.669335  27.948     small  10Nov2025       night
# 2      Ch4  2.927729  27.948     small  10Nov2025       night
# 3      Ch2  8.201904  28.233  cylinder  10Nov2025       night
# 4      Ch3  8.417165  28.233  cylinder  10Nov2025       night
# 5      Ch4  7.614524  28.233  cylinder  10Nov2025       night
# 6      Ch2  2.689699  27.921     small  10Nov2025       night
# 7      Ch3  2.420260  27.921     small  10Nov2025       night
# 8      Ch4  4.356231  27.921     small  10Nov2025       night
# 9      Ch2  3.091545  26.846    medium  11Nov2025       night
# 10     Ch3  5.398751  26.846    medium  11Nov2025       night
# 11     Ch4  3.530253  26.846    medium  11Nov2025       night
# 12     Ch2  5.057591  26.750  cylinder  12Nov2025       night
# 13     Ch3  3.395875  26.750  cylinder  12Nov2025       night
# 14     Ch4  7.309404  26.750  cylinder  12Nov2025       night
# 15     Ch2  3.076209  27.948    medium  12Nov2025       night
# 16     Ch3  2.521120  27.948    medium  12Nov2025       night
# 17     Ch4  4.070796  27.948    medium  12Nov2025       night
# 18     Ch2  0.384284  26.813     small  12Nov2025       night
# 19     Ch3  0.517094  26.813     small  12Nov2025       night
# 20     Ch4  0.428332  26.813     small  12Nov2025       night
# 21     Ch2  1.101950  27.142     small  13Nov2025       night
# 22     Ch3  0.901494  27.142     small  13Nov2025       night
# 23     Ch4  1.000536  27.142     small  13Nov2025       night
# 24     Ch2  0.909045  27.185     small  13Nov2025       night
# 25     Ch3  1.117454  27.185     small  13Nov2025       night
# 26     Ch4  1.636708  27.185     small  13Nov2025       night
# 27     Ch2 -0.244219  27.189  cylinder  13Nov2025       night
# 28     Ch3 -0.594461  27.189  cylinder  13Nov2025       night
# 29     Ch4 -0.677802  27.189  cylinder  13Nov2025       night
# 30     Ch2  0.960297  26.728     small  14Nov2025         day
# 31     Ch3  0.911060  26.728     small  14Nov2025         day
# 32     Ch4  1.253524  26.728     small  14Nov2025         day
# 33     Ch2  1.802954  26.568     small  14Nov2025       night
# 34     Ch3  1.285742  26.568     small  14Nov2025       night
# 35     Ch4  0.715764  26.568     small  14Nov2025       night
# 36     Ch2  1.742087  25.773     small  14Nov2025       night
# 37     Ch3  2.114119  25.773     small  14Nov2025       night
# 38     Ch4  2.544361  25.773     small  14Nov2025       night
# 39     Ch2  0.703890  26.004     small  15Nov2025         day
# 40     Ch3  1.351497  26.004     small  15Nov2025         day
# 41     Ch4  2.841919  26.004     small  15Nov2025         day
# 42     Ch2  1.480777  25.551     small  16Nov2025         day
# 43     Ch3  0.924524  25.551     small  16Nov2025         day
# 44     Ch4  1.263315  25.551     small  16Nov2025         day
# 45     Ch2  0.016775  25.716     small  16Nov2025       night
# 46     Ch3 -2.271740  25.716     small  16Nov2025       night
# 47     Ch4 -2.271740  25.716     small  16Nov2025       night
# 48     Ch2  2.591070  25.838     small  16Nov2025       night
# 49     Ch3  1.431436  25.838     small  16Nov2025       night
# 50     Ch4  1.920979  25.838     small  16Nov2025       night
# 51     Ch2  1.990357  25.734     small  17Nov2025         day
# 52     Ch3  1.216022  25.734     small  17Nov2025         day
# 53     Ch4  1.128887  25.734     small  17Nov2025         day
# 54     Ch2  0.143968  25.873     small  17Nov2025         day
# 55     Ch3  0.358965  25.873     small  17Nov2025         day
# 56     Ch4 -1.376993  25.873     small  17Nov2025         day
# 57     Ch2  3.767786  26.550     small  17Nov2025       night
# 58     Ch3  3.069755  26.550     small  17Nov2025       night
# 59     Ch4  2.585346  26.550     small  17Nov2025       night
# 60     Ch2 -0.243931  26.417     small  17Nov2025       night
# 61     Ch3 -0.213223  26.417     small  17Nov2025       night
# 62     Ch4 -1.746633  26.417     small  17Nov2025       night
#
#                                                 notes
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12      Ch2 closest to GoPro, Ch4 farthest from GoPro
# 13      Ch2 closest to GoPro, Ch4 farthest from GoPro
# 14      Ch2 closest to GoPro, Ch4 farthest from GoPro
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                             Same animals as trial4
# 31                             Same animals as trial4
# 32                             Same animals as trial4
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                             Same animals as trial5
# 40                             Same animals as trial5
# 41                             Same animals as trial5
# 42     Ch1 serves as control for both box3 and newbox
# 43     Ch1 serves as control for both box3 and newbox
# 44     Ch1 serves as control for both box3 and newbox
# 45     Ch1 serves as control for both box3 and newbox
# 46     Ch1 serves as control for both box3 and newbox
# 47     Ch1 serves as control for both box3 and newbox
# 48  Same animals as trial6; Ch1 serves as control ...
# 49  Same animals as trial6; Ch1 serves as control ...
# 50  Same animals as trial6; Ch1 serves as control ...
# 51     Ch1 serves as control for both box3 and newbox
# 52     Ch1 serves as control for both box3 and newbox
# 53     Ch1 serves as control for both box3 and newbox
# 54     Ch1 serves as control for both box3 and newbox
# 55     Ch1 serves as control for both box3 and newbox
# 56     Ch1 serves as control for both box3 and newbox
# 57  Same animals as trial7; Ch1 serves as control ...
# 58  Same animals as trial7; Ch1 serves as control ...
# 59  Same animals as trial7; Ch1 serves as control ...
# 60  Same animals as trial7; Ch1 serves as control ...
# 61  Same animals as trial7; Ch1 serves as control ...
# 62  Same animals as trial7; Ch1 serves as control ...

# %%
# Display a formatted table (excluding the 'file' and 'notes' columns) for quick review
if 'agg_df' in locals() and not agg_df.empty:
    display_cols = [col for col in agg_df.columns if col not in ('file', 'notes')]
    display(agg_df[display_cols])
else:
    print("No data available for display.")
# Out:
#        trial   brick channel  uL_mg_hr  temp_C    vessel       date  \
# 0     trial1    box2     Ch2  2.708969  27.948     small  10Nov2025
# 1     trial1    box2     Ch3  3.669335  27.948     small  10Nov2025
# 2     trial1    box2     Ch4  2.927729  27.948     small  10Nov2025
# 3     trial1    box3     Ch2  8.201904  28.233  cylinder  10Nov2025
# 4     trial1    box3     Ch3  8.417165  28.233  cylinder  10Nov2025
# 5     trial1    box3     Ch4  7.614524  28.233  cylinder  10Nov2025
# 6     trial1  newbox     Ch2  2.689699  27.921     small  10Nov2025
# 7     trial1  newbox     Ch3  2.420260  27.921     small  10Nov2025
# 8     trial1  newbox     Ch4  4.356231  27.921     small  10Nov2025
# 9     trial2  newbox     Ch2  3.091545  26.846    medium  11Nov2025
# 10    trial2  newbox     Ch3  5.398751  26.846    medium  11Nov2025
# 11    trial2  newbox     Ch4  3.530253  26.846    medium  11Nov2025
# 12    trial3    box2     Ch2  5.057591  26.750  cylinder  12Nov2025
# 13    trial3    box2     Ch3  3.395875  26.750  cylinder  12Nov2025
# 14    trial3    box2     Ch4  7.309404  26.750  cylinder  12Nov2025
# 15    trial3    box3     Ch2  3.076209  27.948    medium  12Nov2025
# 16    trial3    box3     Ch3  2.521120  27.948    medium  12Nov2025
# 17    trial3    box3     Ch4  4.070796  27.948    medium  12Nov2025
# 18    trial3  newbox     Ch2  0.384284  26.813     small  12Nov2025
# 19    trial3  newbox     Ch3  0.517094  26.813     small  12Nov2025
# 20    trial3  newbox     Ch4  0.428332  26.813     small  12Nov2025
# 21    trial4    box2     Ch2  1.101950  27.142     small  13Nov2025
# 22    trial4    box2     Ch3  0.901494  27.142     small  13Nov2025
# 23    trial4    box2     Ch4  1.000536  27.142     small  13Nov2025
# 24    trial4    box3     Ch2  0.909045  27.185     small  13Nov2025
# 25    trial4    box3     Ch3  1.117454  27.185     small  13Nov2025
# 26    trial4    box3     Ch4  1.636708  27.185     small  13Nov2025
# 27    trial4  newbox     Ch2 -0.244219  27.189  cylinder  13Nov2025
# 28    trial4  newbox     Ch3 -0.594461  27.189  cylinder  13Nov2025
# 29    trial4  newbox     Ch4 -0.677802  27.189  cylinder  13Nov2025
# 30  trial4.5    box2     Ch2  0.960297  26.728     small  14Nov2025
# 31  trial4.5    box2     Ch3  0.911060  26.728     small  14Nov2025
# 32  trial4.5    box2     Ch4  1.253524  26.728     small  14Nov2025
# 33    trial5    box3     Ch2  1.802954  26.568     small  14Nov2025
# 34    trial5    box3     Ch3  1.285742  26.568     small  14Nov2025
# 35    trial5    box3     Ch4  0.715764  26.568     small  14Nov2025
# 36    trial5  newbox     Ch2  1.742087  25.773     small  14Nov2025
# 37    trial5  newbox     Ch3  2.114119  25.773     small  14Nov2025
# 38    trial5  newbox     Ch4  2.544361  25.773     small  14Nov2025
# 39  trial5.5  newbox     Ch2  0.703890  26.004     small  15Nov2025
# 40  trial5.5  newbox     Ch3  1.351497  26.004     small  15Nov2025
# 41  trial5.5  newbox     Ch4  2.841919  26.004     small  15Nov2025
# 42    trial6  newbox     Ch2  1.480777  25.551     small  16Nov2025
# 43    trial6  newbox     Ch3  0.924524  25.551     small  16Nov2025
# 44    trial6  newbox     Ch4  1.263315  25.551     small  16Nov2025
# 45  trial6.5    box3     Ch2  0.016775  25.716     small  16Nov2025
# 46  trial6.5    box3     Ch3 -2.271740  25.716     small  16Nov2025
# 47  trial6.5    box3     Ch4 -2.271740  25.716     small  16Nov2025
# 48  trial6.5  newbox     Ch2  2.591070  25.838     small  16Nov2025
# 49  trial6.5  newbox     Ch3  1.431436  25.838     small  16Nov2025
# 50  trial6.5  newbox     Ch4  1.920979  25.838     small  16Nov2025
# 51    trial7  newbox     Ch2  1.990357  25.734     small  17Nov2025
# 52    trial7  newbox     Ch3  1.216022  25.734     small  17Nov2025
# 53    trial7  newbox     Ch4  1.128887  25.734     small  17Nov2025
# 54    trial7    box3     Ch2  0.143968  25.873     small  17Nov2025
# 55    trial7    box3     Ch3  0.358965  25.873     small  17Nov2025
# 56    trial7    box3     Ch4 -1.376993  25.873     small  17Nov2025
# 57  trial7.5  newbox     Ch2  3.767786  26.550     small  17Nov2025
# 58  trial7.5  newbox     Ch3  3.069755  26.550     small  17Nov2025
# 59  trial7.5  newbox     Ch4  2.585346  26.550     small  17Nov2025
# 60  trial7.5    box3     Ch2 -0.243931  26.417     small  17Nov2025
# 61  trial7.5    box3     Ch3 -0.213223  26.417     small  17Nov2025
# 62  trial7.5    box3     Ch4 -1.746633  26.417     small  17Nov2025
#
#    environment
# 0        night
# 1        night
# 2        night
# 3        night
# 4        night
# 5        night
# 6        night
# 7        night
# 8        night
# 9        night
# 10       night
# 11       night
# 12       night
# 13       night
# 14       night
# 15       night
# 16       night
# 17       night
# 18       night
# 19       night
# 20       night
# 21       night
# 22       night
# 23       night
# 24       night
# 25       night
# 26       night
# 27       night
# 28       night
# 29       night
# 30         day
# 31         day
# 32         day
# 33       night
# 34       night
# 35       night
# 36       night
# 37       night
# 38       night
# 39         day
# 40         day
# 41         day
# 42         day
# 43         day
# 44         day
# 45       night
# 46       night
# 47       night
# 48       night
# 49       night
# 50       night
# 51         day
# 52         day
# 53         day
# 54         day
# 55         day
# 56         day
# 57       night
# 58       night
# 59       night
# 60       night
# 61       night
# 62       night

# %% [markdown]
# ## Quick Statistics by Group -- ignores rows with rates less than zero

# %%
import matplotlib.pyplot as plt
import numpy as np


if 'agg_df' in locals() and not agg_df.empty:
    # Remove rows with negative consumption
    agg_df = agg_df[agg_df['uL_mg_hr'] >= 0].copy()
    # Group by vessel and environment if those columns exist
    group_cols = [col for col in ['vessel', 'environment'] if col in agg_df.columns]

    
    if group_cols:
        stats = agg_df.groupby(group_cols)['uL_mg_hr'].agg(['count', 'mean', 'std', 'min', 'max'])
        print("\nSummary statistics by group:")
        display(stats)
        
        # Create box and whisker plot with individual data points
        fig, ax = plt.subplots(figsize=(12, 6))
        
        # Create a combined grouping column for x-axis
        agg_df['group'] = agg_df['vessel'] + '\n' + agg_df['environment']
        
        # Get unique groups and sort them
        groups = agg_df['group'].unique()
        groups = sorted(groups)
        
        # Prepare data for box plot
        data_by_group = [agg_df[agg_df['group'] == g]['uL_mg_hr'].values for g in groups]
        
        # Create box plot
        bp = ax.boxplot(data_by_group, labels=groups, patch_artist=True,
                        widths=0.6, showfliers=False)
        
        # Style the boxes
        for patch in bp['boxes']:
            patch.set_facecolor('lightblue')
            patch.set_alpha(0.7)
        
        # Overlay individual data points with jitter
        for i, group in enumerate(groups):
            y_data = agg_df[agg_df['group'] == group]['uL_mg_hr'].values
            # Add jitter to x positions
            x_data = np.random.normal(i + 1, 0.04, size=len(y_data))
            ax.scatter(x_data, y_data, alpha=0.6, s=50, c='darkblue', edgecolors='black', linewidth=0.5)
        
        # Labels and formatting
        ax.set_ylabel('Metabolic Rate (µL O₂/mg/hr)', fontsize=12, fontweight='bold')
        ax.set_xlabel('Vessel Type / Environment', fontsize=12, fontweight='bold')
        ax.set_title('Metabolic Rate Distribution by Vessel and Environment', fontsize=14, fontweight='bold', pad=20)
        ax.grid(axis='y', alpha=0.3, linestyle='--')
        
        # Rotate x-axis labels if needed
        plt.xticks(rotation=0, ha='center')
        
        plt.tight_layout()
        plt.show()
        
    else:
        print("\nOverall statistics:")
        print(agg_df['uL_mg_hr'].describe())
else:
    print("No data available for statistics.")
# Out:
# Summary statistics by group:
#                       count      mean       std       min       max
# vessel   environment
# cylinder night            6  6.666077  2.000997  3.395875  8.417165
# medium   night            6  3.614779  1.015635  2.521120  5.398751
# small    day             14  1.180643  0.663023  0.143968  2.841919
#          night           28  1.869903  1.123344  0.016775  4.356231
# /var/folders/pg/rkmvtptx175d4dsj5fd6w4d40000gp/T/ipykernel_9458/3996297587.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_by_group, labels=groups, patch_artist=True,

# %% [markdown]
# ## Statistical Comparison: Day vs Night
#
# Perform statistical tests to determine if metabolic rates differ significantly between day and night conditions.

# %%
from scipy import stats

if 'agg_df' in locals() and not agg_df.empty:
    # Remove rows with negative consumption
    filtered_df = agg_df[agg_df['uL_mg_hr'] >= 0].copy()
    # Test for each vessel type separately
    vessel_types = filtered_df['vessel'].unique()
    
    print("Statistical Tests: Day vs Night Metabolic Rates")
    print("=" * 70)
    
    for vessel in vessel_types:
        vessel_data = filtered_df[filtered_df['vessel'] == vessel]
        day_data = vessel_data[vessel_data['environment'] == 'day']['uL_mg_hr'].values
        night_data = vessel_data[vessel_data['environment'] == 'night']['uL_mg_hr'].values
        
        if len(day_data) > 0 and len(night_data) > 0:
            # Perform t-test (assumes normality)
            t_stat, p_value_t = stats.ttest_ind(night_data, day_data)
            
            # Perform Mann-Whitney U test (non-parametric alternative)
            u_stat, p_value_u = stats.mannwhitneyu(night_data, day_data, alternative='two-sided')
            
            print(f"\n{vessel.upper()} VESSELS:")
            print(f"  Night: n={len(night_data)}, mean={night_data.mean():.2f}, std={night_data.std():.2f}")
            print(f"  Day:   n={len(day_data)}, mean={day_data.mean():.2f}, std={day_data.std():.2f}")
            print(f"  Difference: {night_data.mean() - day_data.mean():.2f} µL O₂/mg/hr")
            print(f"  % Change: {((day_data.mean() - night_data.mean()) / night_data.mean() * 100):.1f}%")
            print(f"\n  Independent t-test:")
            print(f"    t-statistic = {t_stat:.3f}, p-value = {p_value_t:.4f}")
            print(f"    {'SIGNIFICANT' if p_value_t < 0.05 else 'NOT significant'} at α=0.05")
            print(f"\n  Mann-Whitney U test (non-parametric):")
            print(f"    U-statistic = {u_stat:.1f}, p-value = {p_value_u:.4f}")
            print(f"    {'SIGNIFICANT' if p_value_u < 0.05 else 'NOT significant'} at α=0.05")
        else:
            print(f"\n{vessel.upper()} VESSELS:")
            print(f"  Insufficient data for comparison (day={len(day_data)}, night={len(night_data)})")
    
    print("\n" + "=" * 70)
else:
    print("No data available for statistical analysis.")
# Out:
# Statistical Tests: Day vs Night Metabolic Rates
# ======================================================================
#
# SMALL VESSELS:
#   Night: n=28, mean=1.87, std=1.10
#   Day:   n=14, mean=1.18, std=0.64
#   Difference: 0.69 µL O₂/mg/hr
#   % Change: -36.9%
#
#   Independent t-test:
#     t-statistic = 2.111, p-value = 0.0410
#     SIGNIFICANT at α=0.05
#
#   Mann-Whitney U test (non-parametric):
#     U-statistic = 263.0, p-value = 0.0760
#     NOT significant at α=0.05
#
# CYLINDER VESSELS:
#   Insufficient data for comparison (day=0, night=6)
#
# MEDIUM VESSELS:
#   Insufficient data for comparison (day=0, night=6)
#
# ======================================================================

# %%
# --- Merge agg_df with signal_rate_summary.csv to create merged_df ---
import pandas as pd

# Load the signal rate summary
signal_rate_path = OUT_DIR / 'signal_rate_summary.csv'
signal_df = pd.read_csv(signal_rate_path)

# Ensure columns are named consistently for merging
# (trial, brick, channel must exist in both dataframes)

# Merge only for rows where vessel == 'cylinder'
cylinder_mask = agg_df['vessel'] == 'cylinder'
agg_df_cyl = agg_df[cylinder_mask].copy()
agg_df_non_cyl = agg_df[~cylinder_mask].copy()

# Merge signal_rate into cylinder rows by trial, brick, channel
merged_cyl = pd.merge(
    agg_df_cyl,
    signal_df[['trial', 'brick', 'channel', 'signal_rate']],
    on=['trial', 'brick', 'channel'],
    how='left'
)

# For non-cylinder rows, set signal_rate to 0
agg_df_non_cyl['signal_rate'] = 0

# Concatenate back together
merged_df = pd.concat([merged_cyl, agg_df_non_cyl], ignore_index=True)

# Optional: sort for readability
merged_df = merged_df.sort_values(['trial', 'brick', 'channel']).reset_index(drop=True)

display(merged_df.head())
# Out:
#     trial brick                                               file channel  \
# 0  trial1  box2  /Users/oakley/Documents/GitHub/signal_respirom...     Ch2
# 1  trial1  box2  /Users/oakley/Documents/GitHub/signal_respirom...     Ch3
# 2  trial1  box2  /Users/oakley/Documents/GitHub/signal_respirom...     Ch4
# 3  trial1  box3  /Users/oakley/Documents/GitHub/signal_respirom...     Ch2
# 4  trial1  box3  /Users/oakley/Documents/GitHub/signal_respirom...     Ch3
#
#    uL_mg_hr  temp_C    vessel       date environment notes            group  \
# 0  2.708969  27.948     small  10Nov2025       night   NaN     small\nnight
# 1  3.669335  27.948     small  10Nov2025       night   NaN     small\nnight
# 2  2.927729  27.948     small  10Nov2025       night   NaN     small\nnight
# 3  8.201904  28.233  cylinder  10Nov2025       night   NaN  cylinder\nnight
# 4  8.417165  28.233  cylinder  10Nov2025       night   NaN  cylinder\nnight
#
#    signal_rate
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     9.745342
# 4     0.981366

# %%
# Plot signal_rate vs uL_mg_hr, color by vessel type
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))

# Only plot rows where signal_rate is not null (should be all, but just in case)
plot_df = merged_df.copy()

sns.scatterplot(
    data=plot_df,
    x='signal_rate',
    y='uL_mg_hr',
    hue='vessel',
    palette={'cylinder': 'orange', 'medium': 'green', 'small': 'steelblue'},
    s=60,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('Signal Rate')
plt.ylabel('Metabolic Rate (uL O₂/mg/hr)')
plt.title('Signal Rate vs Metabolic Rate by Vessel Type')
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(title='Vessel Type')
plt.tight_layout()
plt.show()

# %%
from pathlib import Path
import re

r_dir = Path('/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r')

# Pattern to find ANY incorrect subset syntax (using regex)
incorrect_pattern = re.compile(r'trim_data<-subset\(Data,hours>=[\d.]+ &Data,hours<=[\d.]+\)')

# Process all .R files
for r_file in r_dir.glob('*.R'):
    with open(r_file, 'r') as f:
        lines = f.readlines()
    
    modified = False
    new_lines = []
    
    for i, line in enumerate(lines):
        if incorrect_pattern.search(line) and not line.strip().startswith('#'):
            # Found incorrect syntax that's not already commented out
            # Comment out the old line
            new_lines.append(f'#{line.rstrip()} #SYNTAX ERROR - this included all data!\n')
            
            # Extract the hour values to preserve them
            match = re.search(r'hours>=([\d.]+) &Data,hours<=([\d.]+)', line)
            if match:
                start_hour = match.group(1)
                end_hour = match.group(2)
                new_lines.append(f'trim_data<-subset(Data, hours>={start_hour} & hours<={end_hour}) #CORRECTED\n')
            else:
                # Fallback to default
                new_lines.append('trim_data<-subset(Data, hours>=1 & hours<=8) #CORRECTED\n')
            
            modified = True
            print(f"  Fixed line in {r_file.name}: {line.strip()}")
        else:
            new_lines.append(line)
    
    if modified:
        # Backup original
        backup_file = r_file.with_suffix('.R.bak')
        with open(backup_file, 'w') as f:
            f.writelines(lines)
        
        # Write corrected file
        with open(r_file, 'w') as f:
            f.writelines(new_lines)
        
        print(f"✓ Fixed: {r_file.name}\n")
    else:
        print(f"✓ No changes needed: {r_file.name}")

print("\nAll R scripts have been processed!")
# Out:
# ✓ No changes needed: newpyro-trial7-dark.R
# ✓ No changes needed: newpyro-trial2.R
# ✓ No changes needed: box3-trial7-dark.R
# ✓ No changes needed: box2-trial2.R
# ✓ No changes needed: newpyro-trial5.R
# ✓ No changes needed: newpyro-trial1.R
# ✓ No changes needed: box3-trial5.R
# ✓ No changes needed: box2-trial5.R
# ✓ No changes needed: box2-trial1.R
# ✓ No changes needed: box3-trial1.R
# ✓ No changes needed: box3-trial6-dark.R
# ✓ No changes needed: newpyro-trial7-light.R
# ✓ No changes needed: newpyro-trial4.R
# ✓ No changes needed: newpyro-trial6-dark.R
# ✓ No changes needed: box3-trial7-light.R
# ✓ No changes needed: box3-trial6-light.R
# ✓ No changes needed: box2-trial4.R
# ✓ No changes needed: box3-trial4.R
# ✓ No changes needed: newpyro-trial6-light.R
# ✓ No changes needed: box3-trial4-light.R
# ✓ No changes needed: newpyro-trial3.R
# ✓ No changes needed: newpyro-trial5-light.R
# ✓ No changes needed: box2-trial4-light.R
# ✓ No changes needed: box2-trial3.R
# ✓ No changes needed: box3-trial3.R
# ✓ No changes needed: box3-trial5-light.R
#
# All R scripts have been processed!

# %%
import re
from pathlib import Path

r_dir = Path("/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r")

setwd_old = 'setwd("F:/Ostracod Respirometry")'
setwd_block = [
    "#File directory Adriana\n",
    '#setwd("F:/Ostracod Respirometry")\n',
    "\n",
    "#File directory Todd\n",
    'setwd("/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r")\n',
]

plot_patterns = (
    re.compile(r'^\s*plot\('),
    re.compile(r'^\s*lot\('),  # catches the typo line
)

changed_files = []

for r_file in r_dir.glob("*.R"):
    with open(r_file, "r") as f:
        lines = f.readlines()

    needs_setwd = any(setwd_old in ln and not ln.lstrip().startswith("#") for ln in lines)
    already_block = any("File directory Todd" in ln for ln in lines)

    new_lines = []
    modified = False

    i = 0
    while i < len(lines):
        line = lines[i]

        # Replace setwd block once if needed
        if needs_setwd and (setwd_old in line) and not line.lstrip().startswith("#"):
            new_lines.extend(setwd_block)
            modified = True
            i += 1
            continue

        # Comment plot/lot lines if not already commented
        if not line.lstrip().startswith("#") and any(pat.search(line) for pat in plot_patterns):
            new_lines.append("#" + line.lstrip())  # comment while trimming leading spaces
            modified = True
            i += 1
            continue

        new_lines.append(line)
        i += 1

    # If already has the Todd block, leave as-is
    if already_block:
        needs_setwd = False  # don't treat as modified for setwd reason

    if modified:
        with open(r_file, "w") as f:
            f.writelines(new_lines)
        changed_files.append(r_file.name)

print("Updated files:" if changed_files else "No changes needed.")
for name in changed_files:
    print(f"  ✓ {name}")
# Out:
# No changes needed.

# %%
import re
from pathlib import Path
import pandas as pd

base = Path("/Users/oakley/Documents/GitHub/signal_respirometry/data/adriana_final_r")
files = [
    "newpyro-trial7-dark.R","newpyro-trial2.R","box3-trial7-dark.R","box2-trial2.R","newpyro-trial5.R",
    "newpyro-trial1.R","box3-trial5.R","box2-trial5.R","box2-trial1.R","box3-trial1.R","box3-trial6-dark.R",
    "newpyro-trial7-light.R","newpyro-trial4.R","newpyro-trial6-dark.R","box3-trial7-light.R","box3-trial6-light.R",
    "box2-trial4.R","box3-trial4.R","newpyro-trial6-light.R","box3-trial4-light.R","newpyro-trial3.R",
    "newpyro-trial5-light.R","box2-trial4-light.R","box2-trial3.R","box3-trial3.R","box3-trial5-light.R",
]

mass_re = re.compile(r"^Mass(\d+)\s*<-\s*([0-9.eE+-]+)")

records = []
for fname in files:
    path = base / fname
    if not path.exists():
        continue
    brick_raw, trial_part = path.stem.split("-", 1)
    box = "newbox" if brick_raw == "newpyro" else brick_raw  # map newpyro→newbox
    with path.open() as f:
        for line in f:
            m = mass_re.match(line.strip())
            if m:
                channel = f"Ch{int(m.group(1))}"
                mass = float(m.group(2))
                records.append({
                    "box": box,
                    "trial": trial_part,   # includes light/dark suffix if present
                    "channel": channel,
                    "mass_g": mass,
                    "file": str(path),
                })

df = pd.DataFrame(records).sort_values(["box","trial","channel"]).reset_index(drop=True)
display(df)
# Out:
#        box         trial channel    mass_g  \
# 0     box2        trial1     Ch2  0.000226
# 1     box2        trial1     Ch3  0.000210
# 2     box2        trial1     Ch4  0.000270
# 3     box2        trial2     Ch2  0.000231
# 4     box2        trial2     Ch3  0.000254
# 5     box2        trial2     Ch4  0.000211
# 6     box2        trial3     Ch2  0.004900
# 7     box2        trial3     Ch3  0.004700
# 8     box2        trial3     Ch4  0.005059
# 9     box2        trial4     Ch2  0.000219
# 10    box2        trial4     Ch3  0.000374
# 11    box2        trial4     Ch4  0.000207
# 12    box2  trial4-light     Ch2  0.000219
# 13    box2  trial4-light     Ch3  0.000374
# 14    box2  trial4-light     Ch4  0.000207
# 15    box2        trial5     Ch2  0.004400
# 16    box2        trial5     Ch4  0.004800
# 17    box3        trial1     Ch2  0.007600
# 18    box3        trial1     Ch3  0.007222
# 19    box3        trial1     Ch4  0.007333
# 20    box3        trial3     Ch2  0.001100
# 21    box3        trial3     Ch3  0.001000
# 22    box3        trial3     Ch4  0.001125
# 23    box3        trial4     Ch2  0.000295
# 24    box3        trial4     Ch3  0.000221
# 25    box3        trial4     Ch4  0.000252
# 26    box3  trial4-light     Ch3  0.000221
# 27    box3  trial4-light     Ch4  0.000252
# 28    box3        trial5     Ch2  0.000189
# 29    box3        trial5     Ch3  0.000335
# 30    box3        trial5     Ch4  0.000363
# 31    box3  trial5-light     Ch2  0.000189
# 32    box3  trial5-light     Ch3  0.000335
# 33    box3  trial5-light     Ch4  0.000363
# 34    box3   trial6-dark     Ch2  0.000240
# 35    box3   trial6-dark     Ch4  0.000208
# 36    box3  trial6-light     Ch2  0.000240
# 37    box3  trial6-light     Ch3  0.000258
# 38    box3  trial6-light     Ch4  0.000208
# 39    box3   trial7-dark     Ch2  0.000264
# 40    box3   trial7-dark     Ch3  0.000253
# 41    box3   trial7-dark     Ch4  0.000249
# 42    box3  trial7-light     Ch2  0.000264
# 43    box3  trial7-light     Ch3  0.000253
# 44    box3  trial7-light     Ch4  0.000249
# 45  newbox        trial1     Ch2  0.000251
# 46  newbox        trial1     Ch3  0.000297
# 47  newbox        trial1     Ch4  0.000181
# 48  newbox        trial2     Ch2  0.001100
# 49  newbox        trial2     Ch3  0.001125
# 50  newbox        trial2     Ch4  0.001100
# 51  newbox        trial3     Ch2  0.000217
# 52  newbox        trial3     Ch3  0.000199
# 53  newbox        trial3     Ch4  0.000255
# 54  newbox        trial4     Ch2  0.005294
# 55  newbox        trial4     Ch3  0.004800
# 56  newbox        trial4     Ch4  0.004900
# 57  newbox        trial5     Ch2  0.000223
# 58  newbox        trial5     Ch3  0.000270
# 59  newbox        trial5     Ch4  0.000228
# 60  newbox  trial5-light     Ch2  0.000223
# 61  newbox  trial5-light     Ch3  0.000270
# 62  newbox  trial5-light     Ch4  0.000228
# 63  newbox   trial6-dark     Ch2  0.000193
# 64  newbox   trial6-dark     Ch3  0.000241
# 65  newbox   trial6-dark     Ch4  0.000228
# 66  newbox  trial6-light     Ch2  0.000193
# 67  newbox  trial6-light     Ch3  0.000241
# 68  newbox  trial6-light     Ch4  0.000228
# 69  newbox   trial7-dark     Ch2  0.000228
# 70  newbox   trial7-dark     Ch3  0.000263
# 71  newbox   trial7-dark     Ch4  0.000236
# 72  newbox  trial7-light     Ch2  0.000228
# 73  newbox  trial7-light     Ch3  0.000263
# 74  newbox  trial7-light     Ch4  0.000236
#
#                                                  file
# 0   /Users/oakley/Documents/GitHub/signal_respirom...
# 1   /Users/oakley/Documents/GitHub/signal_respirom...
# 2   /Users/oakley/Documents/GitHub/signal_respirom...
# 3   /Users/oakley/Documents/GitHub/signal_respirom...
# 4   /Users/oakley/Documents/GitHub/signal_respirom...
# 5   /Users/oakley/Documents/GitHub/signal_respirom...
# 6   /Users/oakley/Documents/GitHub/signal_respirom...
# 7   /Users/oakley/Documents/GitHub/signal_respirom...
# 8   /Users/oakley/Documents/GitHub/signal_respirom...
# 9   /Users/oakley/Documents/GitHub/signal_respirom...
# 10  /Users/oakley/Documents/GitHub/signal_respirom...
# 11  /Users/oakley/Documents/GitHub/signal_respirom...
# 12  /Users/oakley/Documents/GitHub/signal_respirom...
# 13  /Users/oakley/Documents/GitHub/signal_respirom...
# 14  /Users/oakley/Documents/GitHub/signal_respirom...
# 15  /Users/oakley/Documents/GitHub/signal_respirom...
# 16  /Users/oakley/Documents/GitHub/signal_respirom...
# 17  /Users/oakley/Documents/GitHub/signal_respirom...
# 18  /Users/oakley/Documents/GitHub/signal_respirom...
# 19  /Users/oakley/Documents/GitHub/signal_respirom...
# 20  /Users/oakley/Documents/GitHub/signal_respirom...
# 21  /Users/oakley/Documents/GitHub/signal_respirom...
# 22  /Users/oakley/Documents/GitHub/signal_respirom...
# 23  /Users/oakley/Documents/GitHub/signal_respirom...
# 24  /Users/oakley/Documents/GitHub/signal_respirom...
# 25  /Users/oakley/Documents/GitHub/signal_respirom...
# 26  /Users/oakley/Documents/GitHub/signal_respirom...
# 27  /Users/oakley/Documents/GitHub/signal_respirom...
# 28  /Users/oakley/Documents/GitHub/signal_respirom...
# 29  /Users/oakley/Documents/GitHub/signal_respirom...
# 30  /Users/oakley/Documents/GitHub/signal_respirom...
# 31  /Users/oakley/Documents/GitHub/signal_respirom...
# 32  /Users/oakley/Documents/GitHub/signal_respirom...
# 33  /Users/oakley/Documents/GitHub/signal_respirom...
# 34  /Users/oakley/Documents/GitHub/signal_respirom...
# 35  /Users/oakley/Documents/GitHub/signal_respirom...
# 36  /Users/oakley/Documents/GitHub/signal_respirom...
# 37  /Users/oakley/Documents/GitHub/signal_respirom...
# 38  /Users/oakley/Documents/GitHub/signal_respirom...
# 39  /Users/oakley/Documents/GitHub/signal_respirom...
# 40  /Users/oakley/Documents/GitHub/signal_respirom...
# 41  /Users/oakley/Documents/GitHub/signal_respirom...
# 42  /Users/oakley/Documents/GitHub/signal_respirom...
# 43  /Users/oakley/Documents/GitHub/signal_respirom...
# 44  /Users/oakley/Documents/GitHub/signal_respirom...
# 45  /Users/oakley/Documents/GitHub/signal_respirom...
# 46  /Users/oakley/Documents/GitHub/signal_respirom...
# 47  /Users/oakley/Documents/GitHub/signal_respirom...
# 48  /Users/oakley/Documents/GitHub/signal_respirom...
# 49  /Users/oakley/Documents/GitHub/signal_respirom...
# 50  /Users/oakley/Documents/GitHub/signal_respirom...
# 51  /Users/oakley/Documents/GitHub/signal_respirom...
# 52  /Users/oakley/Documents/GitHub/signal_respirom...
# 53  /Users/oakley/Documents/GitHub/signal_respirom...
# 54  /Users/oakley/Documents/GitHub/signal_respirom...
# 55  /Users/oakley/Documents/GitHub/signal_respirom...
# 56  /Users/oakley/Documents/GitHub/signal_respirom...
# 57  /Users/oakley/Documents/GitHub/signal_respirom...
# 58  /Users/oakley/Documents/GitHub/signal_respirom...
# 59  /Users/oakley/Documents/GitHub/signal_respirom...
# 60  /Users/oakley/Documents/GitHub/signal_respirom...
# 61  /Users/oakley/Documents/GitHub/signal_respirom...
# 62  /Users/oakley/Documents/GitHub/signal_respirom...
# 63  /Users/oakley/Documents/GitHub/signal_respirom...
# 64  /Users/oakley/Documents/GitHub/signal_respirom...
# 65  /Users/oakley/Documents/GitHub/signal_respirom...
# 66  /Users/oakley/Documents/GitHub/signal_respirom...
# 67  /Users/oakley/Documents/GitHub/signal_respirom...
# 68  /Users/oakley/Documents/GitHub/signal_respirom...
# 69  /Users/oakley/Documents/GitHub/signal_respirom...
# 70  /Users/oakley/Documents/GitHub/signal_respirom...
# 71  /Users/oakley/Documents/GitHub/signal_respirom...
# 72  /Users/oakley/Documents/GitHub/signal_respirom...
# 73  /Users/oakley/Documents/GitHub/signal_respirom...
# 74  /Users/oakley/Documents/GitHub/signal_respirom...
